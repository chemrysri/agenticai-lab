# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-5.6.2-py3-none-any.whl.metadata (33 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.12.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\sasi\appdata\roaming\python\python311\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sasi\appdata\roaming\python\python311\site-packages (from transformers) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from transformers) (6.0)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.4.4-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 2.0 MB/s eta 0:00:00
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers)
#   Downloading typer-0.24.2-py3-none-any.whl.metadata (15 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from transformers) (4.66.5)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\sasi\appdata\roaming\python\python311\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Collecting click>=8.2.1 (from typer->transformers)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=12.3.0 in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from typer->transformers) (13.3.5)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.2.0)
# Requirement already satisfied: certifi in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.4)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sasi\appdata\roaming\python\python311\site-packages (from rich>=12.3.0->typer->transformers) (2.13.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sasi\anaconda3\envs\genai\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Downloading transformers-5.6.2-py3-none-any.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/10.4 MB 12.4 MB/s eta 0:00:01
#    --------- ------------------------------ 2.4/10.4 MB 30.9 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/10.4 MB 36.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.1/10.4 MB 38.7 MB/s eta 0:00:01
#    -------------------------------- ------- 8.4/10.4 MB 41.3 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.4 MB 46.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 40.9 MB/s eta 0:00:00
# Downloading huggingface_hub-1.12.0-py3-none-any.whl (646 kB)
#    ---------------------------------------- 0.0/646.8 kB ? eta -:--:--
#    --------------------------------------- 646.8/646.8 kB 39.8 MB/s eta 0:00:00
# Downloading regex-2026.4.4-cp311-cp311-win_amd64.whl (278 kB)
#    ---------------------------------------- 0.0/278.4 kB ? eta -:--:--
#    --------------------------------------- 278.4/278.4 kB 16.8 MB/s eta 0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
#    ---------------------------------------- 0.0/341.4 kB ? eta -:--:--
#    --------------------------------------- 341.4/341.4 kB 22.1 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------  2.7/2.7 MB 85.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 58.2 MB/s eta 0:00:00
# Downloading typer-0.24.2-py3-none-any.whl (55 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 2.9 MB/s eta 0:00:00
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
#    ---------------------------------------- 0.0/110.5 kB ? eta -:--:--
#    ---------------------------------------- 110.5/110.5 kB ? eta 0:00:00
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
#    ---------------------------------------- 0.0/202.6 kB ? eta -:--:--
#    --------------------------------------- 202.6/202.6 kB 12.8 MB/s eta 0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ------------------------ --------------- 2.2/3.7 MB 148.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 47.0 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB ? eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#    ---------------------------------------- 78.8/78.8 kB 4.3 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: shellingham, safetensors, regex, hf-xet, h11, fsspec, filelock, click, annotated-doc, httpcore, typer, httpx, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gtts 2.5.2 requires click<8.2,>=7.1, but you have click 8.3.3 which is incompatible.
# streamlit 1.32.0 requires pillow<11,>=7.1.0, but you have pillow 11.0.0 which is incompatible.
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
# Successfully installed annotated-doc-0.0.4 click-8.3.3 filelock-3.29.0 fsspec-2026.3.0 h11-0.16.0 hf-xet-1.4.3 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.12.0 regex-2026.4.4 safetensors-0.7.0 shellingham-1.5.4 tokenizers-0.22.2 transformers-5.6.2 typer-0.24.2

# %%
from transformers import AutoTokenizer,AutoModelForSeq2SeqLM
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from transformers import AutoTokenizer,AutoModelForSeq2SeqLM
# ----> 2 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
model_name='deepseek-ai/DeepSeek-V4-Flash'
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 model_name='deepseek-ai/DeepSeek-V4-Flash'
# ----> 2 model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
#       3 tokenizer = AutoTokenizer.from_pretrained(model_name)
#
# File c:\Users\Sasi\anaconda3\envs\genai\Lib\site-packages\transformers\utils\import_utils.py:2040, in DummyObject.__getattribute__(cls, key)
#    2038 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2039     return super().__getattribute__(key)
# -> 2040 requires_backends(cls, cls._backends)
#
# File c:\Users\Sasi\anaconda3\envs\genai\Lib\site-packages\transformers\utils\import_utils.py:2026, in requires_backends(obj, backends)
#    2023         failed.append(msg.format(name))
#    2025 if failed:
# -> 2026     raise ImportError("".join(failed))
#
# ImportError:
# AutoModelForSeq2SeqLM requires the PyTorch library but it was not found in your environment. Check out the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.
